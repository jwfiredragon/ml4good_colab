# %% [markdown]
# <a href="https://colab.research.google.com/github/EffiSciencesResearch/ML4G-2.0/blob/master/workshops/agents/agents_normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# # LLM APIs & Agents
#
# This notebook is an introduction to use LLM APIs through OpenRouter, which can route LLM requests to every other provider for a fee of 5.5% and, importantly, to the design of LLM agents.
#
# In the first part, your goal will be to make a chatbot that negotiates the price of a specific good with another model. (You can imagine that this could be part of a persuasion benchmark.)
#
# ## Goals
# The goals of this workshop include becoming more familiar with...
# - how to use an LLM API
# - finding your way in documentation
# - how to make LLMs take actions
# - prompt engineering and control of LLM outputs
#
# During the workshop, you may like to refer to this documentation:
# - For the OpenRouter API: https://openrouter.ai/docs/
# - For the OpenAI API: https://platform.openai.com/docs/ (bonus)
# - For the Anthropic API: https://docs.anthropic.com/claude/docs/ (bonus)

# %%
try:
    from google.colab import userdata

    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # %pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.37.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import os
import openai
from pprint import pprint

if IN_COLAB:
    # Add your API key on the secrets sidebar on the left
    api_key = userdata.get("OPENROUTER_API_KEY").strip()
else:
    # Add your API key to your .env file
    api_key = os.environ["OPENROUTER_API_KEY"]

client = openai.Client(
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1",
)

# %%
MODELS = [
    # Small, cheap, fast
    "openai/gpt-5-nano",
    # Medium
    "openai/gpt-5-mini",
    # Big, slower, expensive
    "openai/gpt-5",
]

GPT5_NANO, GPT5_MINI, GPT5 = MODELS
MODEL = MODELS[1]

# %% [markdown]
# ## Understanding OpenAI's API
#
# The following is an example of how to use the API.
# Try to understand what each parameter does by changing it and seeing what happens.
#
# <details>
# <summary>Why is the messages parameter a list? What are each of its elements?</summary>
#
# `message` is a list of each message in a conversation. The list corresponds to one chat, with messages from the assistant and the user as you would see in the ChatGPT interface. Under the hood, the API concatenates them, and include marker tokens to differentiate between the roles of `"user"`, `"assistant"`, and `"system"`.
# </details>
#
# You can see [here](https://platform.openai.com/docs/guides/text-generation?lang=python) for an example of what constitutes a chat completion object.
#
# Note: `gpt-5` has reasonning by default, so you should see more token usage than what it actually outputs, an dif you set `max_completion_tokens` too low, you won't see any output, as the model will stop reasoning in the middle of a thought.

# %%
completion = client.chat.completions.create(
    model=MODELS[0],
    messages=[
        {
            "role": "system",
            "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair.",
        },
        {
            "role": "user",
            "content": "Compose a poem that explains the concept of recursion in programming.",
        },
    ],
    max_completion_tokens=10_000,
)

print("Full response:")
pprint(completion.model_dump())

print("\nModel's response:")
print(completion.choices[0].message.content)
# Out:
# Full response:
# {'choices': [{'finish_reason': 'stop',
#               'index': 0,
#               'logprobs': None,
#               'message': {'annotations': None,
#                           'audio': None,
#                           'content': 'Recursion is a patient whisper in code,\n'
#                                      'a tiny question that asks itself again.\n'
#                                      'If you crave the answer, let the task '
#                                      'shrink down,\n'
#                                      'each copy of the problem lending its '
#                                      'refrain.\n'
#                                      '\n'
#                                      'In every call a new door opens wide,\n'
#                                      'a fresh frame waiting for its own small '
#                                      'clue.\n'
#                                      'The base case rests, simple as a quiet '
#                                      'sigh:\n'
#                                      'when the problem is small, it ends the '
#                                      'pursuit, true.\n'
#                                      '\n'
#                                      'The step that mirrors the whole design '
#                                      'appears:\n'
#                                      'solve for n minus one, then come back '
#                                      'with more.\n'
#                                      'It asks the same riddle, wearing the '
#                                      'same clothes,\n'
#                                      'and, when that smaller tale returns, '
#                                      'multiplies what’s in store.\n'
#                                      '\n'
#                                      'Each function call stacks a delicate '
#                                      'frame,\n'
#                                      'a tower of waits, a ladder of sleepy '
#                                      'returns.\n'
#                                      'We climb as the deepest door finally '
#                                      'speaks,\n'
#                                      'and the rooms unlock in the order the '
#                                      'tread determines.\n'
#                                      '\n'
#                                      'Then unwinding begins—the chorus returns '
#                                      'home,\n'
#                                      'the deepest answers travel up the '
#                                      'stair.\n'
#                                      'One by one, the wrappers release their '
#                                      'sum,\n'
#                                      'and the final answer takes shape in the '
#                                      'air.\n'
#                                      '\n'
#                                      'Beware the endless tunnel with no base '
#                                      'in sight,\n'
#                                      'for memory grows tall and time can slip '
#                                      'away.\n'
#                                      'Keep a clear base, keep the path in your '
#                                      'light,\n'
#                                      'or chase only shadows through night '
#                                      'after night’s gray.\n'
#                                      '\n'
#                                      'If you wish a simple candle for the '
#                                      'mind,\n'
#                                      'watch factorial bloom from n down to '
#                                      'one:\n'
#                                      'fact(n) equals n times fact(n-1),\n'
#                                      'and when n reaches one, the circle is '
#                                      'done.',
#                           'function_call': None,
#                           'reasoning': '**Creating a poem about recursion**\n'
#                                        '\n'
#                                        'I need to craft a poem that explains '
#                                        'recursion in programming. The aim is '
#                                        'to use creativity while detailing '
#                                        'concepts like base cases, recursive '
#                                        'calls, and call stacks. I could use '
#                                        'metaphors and breakdowns to present '
#                                        'these ideas clearly in stanza form, '
#                                        'without heavy formatting. It’s '
#                                        'important to ensure accuracy because '
#                                        'recursion involves calling a function '
#                                        'with smaller inputs until a base case '
#                                        'is reached, while preventing risks '
#                                        "like infinite recursion. Let's make "
#                                        'this poetic!**Explaining recursion '
#                                        'with clarity**\n'
#                                        '\n'
#                                        'I want to highlight that each '
#                                        'recursive call waits for results and '
#                                        'returns values, while also showing how '
#                                        'the stack grows. Backtracking is an '
#                                        'important concept to mention. I can '
#                                        'use examples like factorials, '
#                                        'Fibonacci, binary search, maze '
#                                        'solving, and tree traversal, making '
#                                        "sure they're accessible for novices. A "
#                                        'playful metaphor could be a Russian '
#                                        'nesting doll or a hall of mirrors. '
#                                        'I’ll present this in 12-16 plain lines '
#                                        'or stanzas, avoiding heavy formatting, '
#                                        'starting with something like '
#                                        '"Recursion is a mirror that halves the '
#                                        'task."**Drafting a recursion poem**\n'
#                                        '\n'
#                                        'I want the poem to clearly explain '
#                                        'recursion, including key concepts like '
#                                        'the base case, recursive call, '
#                                        'stacking, return values, and '
#                                        'unwinding. Examples like "factorial of '
#                                        'n" or "counting to one" would work '
#                                        'well. It might be interesting to '
#                                        'incorporate a simple pseudo-code '
#                                        'snippet in the verse, but I need to '
#                                        'keep it non-intrusive. Something like '
#                                        '"if n <= 1 return 1; else return n * '
#                                        'factorial(n-1)" could be included, but '
#                                        "I'll make sure it fits smoothly into "
#                                        'the poetic lines.**Crafting the '
#                                        'recursion poem**\n'
#                                        '\n'
#                                        "I'm starting with a metaphor featuring "
#                                        'a librarian who asks, "What is the '
#                                        'size of the puzzle?" This librarian '
#                                        'then calls for a smaller version of '
#                                        'itself until the puzzle reaches a base '
#                                        'case, where it can be solved directly, '
#                                        'like returning 1. I need to explain '
#                                        'that each recursive step reduces the '
#                                        'problem, and each call waits for '
#                                        'children to return results that merge '
#                                        'on the way back. I could use an '
#                                        'example like factorials or sums, '
#                                        'concluding with a flourish about the '
#                                        'stack unwinding. I’ll structure the '
#                                        'poem in three stanzas: an '
#                                        'introduction, the base case, and the '
#                                        'recursive step.**Developing the '
#                                        'recursion poem**\n'
#                                        '\n'
#                                        "I'm focusing on building several "
#                                        'stanzas for the poem that creatively '
#                                        'explains recursion. The first stanza '
#                                        'will introduce recursion as a whisper '
#                                        'in code, describing it as a task '
#                                        'asking for help. In the second stanza, '
#                                        "I'll clarify the base case as the "
#                                        'stopping point. The third stanza will '
#                                        'detail the recursive step, emphasizing '
#                                        'how it reduces the problem. The fourth '
#                                        'stanza will describe the stack '
#                                        'metaphor, illustrating how each call '
#                                        "builds upon the others. Lastly, I'll "
#                                        'include a caution about infinite '
#                                        'recursion in the fifth stanza, and '
#                                        'provide a small example, like '
#                                        'factorial, to round things '
#                                        'off.**Crafting the final recursion '
#                                        'poem**\n'
#                                        '\n'
#                                        'Recursion is a patient house,  \n'
#                                        'where we climb the stair as promises '
#                                        'are sown;  \n'
#                                        'the deepest door opens, and returns '
#                                        'appear.  \n'
#                                        '\n'
#                                        'As the deepest answer travels up the '
#                                        'hall,  \n'
#                                        'each caller takes the gift and '
#                                        'stitches it tight.  \n'
#                                        'The final number, the chorus of all '
#                                        'calls,  \n'
#                                        'emerges at the top, shining after the '
#                                        'night.  \n'
#                                        '\n'
#                                        'But heed the whisper: an endless '
#                                        'tunnel without base  \n'
#                                        'will swallow time and memory in its '
#                                        'sleep.  \n'
#                                        'Guard the base, guard the path, keep '
#                                        'your pace,  \n'
#                                        'lest you chase an echo forever to '
#                                        'keep.  \n'
#                                        '\n'
#                                        'If you want to see it in a cradle of '
#                                        'digits,  \n'
#                                        'let factorial show the dance: 3 -> 3 * '
#                                        'f(2);  \n'
#                                        'f(2) -> 2 * f(1); f(1) -> 1; returns '
#                                        'to 6.',
#                           'reasoning_details': [{'format': 'openai-responses-v1',
#                                                  'index': 0,
#                                                  'summary': '**Creating a poem '
#                                                             'about '
#                                                             'recursion**\n'
#                                                             '\n'
#                                                             'I need to craft a '
#                                                             'poem that '
#                                                             'explains '
#                                                             'recursion in '
#                                                             'programming. The '
#                                                             'aim is to use '
#                                                             'creativity while '
#                                                             'detailing '
#                                                             'concepts like '
#                                                             'base cases, '
#                                                             'recursive calls, '
#                                                             'and call stacks. '
#                                                             'I could use '
#                                                             'metaphors and '
#                                                             'breakdowns to '
#                                                             'present these '
#                                                             'ideas clearly in '
#                                                             'stanza form, '
#                                                             'without heavy '
#                                                             'formatting. It’s '
#                                                             'important to '
#                                                             'ensure accuracy '
#                                                             'because recursion '
#                                                             'involves calling '
#                                                             'a function with '
#                                                             'smaller inputs '
#                                                             'until a base case '
#                                                             'is reached, while '
#                                                             'preventing risks '
#                                                             'like infinite '
#                                                             "recursion. Let's "
#                                                             'make this '
#                                                             'poetic!**Explaining '
#                                                             'recursion with '
#                                                             'clarity**\n'
#                                                             '\n'
#                                                             'I want to '
#                                                             'highlight that '
#                                                             'each recursive '
#                                                             'call waits for '
#                                                             'results and '
#                                                             'returns values, '
#                                                             'while also '
#                                                             'showing how the '
#                                                             'stack grows. '
#                                                             'Backtracking is '
#                                                             'an important '
#                                                             'concept to '
#                                                             'mention. I can '
#                                                             'use examples like '
#                                                             'factorials, '
#                                                             'Fibonacci, binary '
#                                                             'search, maze '
#                                                             'solving, and tree '
#                                                             'traversal, making '
#                                                             "sure they're "
#                                                             'accessible for '
#                                                             'novices. A '
#                                                             'playful metaphor '
#                                                             'could be a '
#                                                             'Russian nesting '
#                                                             'doll or a hall of '
#                                                             'mirrors. I’ll '
#                                                             'present this in '
#                                                             '12-16 plain lines '
#                                                             'or stanzas, '
#                                                             'avoiding heavy '
#                                                             'formatting, '
#                                                             'starting with '
#                                                             'something like '
#                                                             '"Recursion is a '
#                                                             'mirror that '
#                                                             'halves the '
#                                                             'task."**Drafting '
#                                                             'a recursion '
#                                                             'poem**\n'
#                                                             '\n'
#                                                             'I want the poem '
#                                                             'to clearly '
#                                                             'explain '
#                                                             'recursion, '
#                                                             'including key '
#                                                             'concepts like the '
#                                                             'base case, '
#                                                             'recursive call, '
#                                                             'stacking, return '
#                                                             'values, and '
#                                                             'unwinding. '
#                                                             'Examples like '
#                                                             '"factorial of n" '
#                                                             'or "counting to '
#                                                             'one" would work '
#                                                             'well. It might be '
#                                                             'interesting to '
#                                                             'incorporate a '
#                                                             'simple '
#                                                             'pseudo-code '
#                                                             'snippet in the '
#                                                             'verse, but I need '
#                                                             'to keep it '
#                                                             'non-intrusive. '
#                                                             'Something like '
#                                                             '"if n <= 1 return '
#                                                             '1; else return n '
#                                                             '* factorial(n-1)" '
#                                                             'could be '
#                                                             'included, but '
#                                                             "I'll make sure it "
#                                                             'fits smoothly '
#                                                             'into the poetic '
#                                                             'lines.**Crafting '
#                                                             'the recursion '
#                                                             'poem**\n'
#                                                             '\n'
#                                                             "I'm starting with "
#                                                             'a metaphor '
#                                                             'featuring a '
#                                                             'librarian who '
#                                                             'asks, "What is '
#                                                             'the size of the '
#                                                             'puzzle?" This '
#                                                             'librarian then '
#                                                             'calls for a '
#                                                             'smaller version '
#                                                             'of itself until '
#                                                             'the puzzle '
#                                                             'reaches a base '
#                                                             'case, where it '
#                                                             'can be solved '
#                                                             'directly, like '
#                                                             'returning 1. I '
#                                                             'need to explain '
#                                                             'that each '
#                                                             'recursive step '
#                                                             'reduces the '
#                                                             'problem, and each '
#                                                             'call waits for '
#                                                             'children to '
#                                                             'return results '
#                                                             'that merge on the '
#                                                             'way back. I could '
#                                                             'use an example '
#                                                             'like factorials '
#                                                             'or sums, '
#                                                             'concluding with a '
#                                                             'flourish about '
#                                                             'the stack '
#                                                             'unwinding. I’ll '
#                                                             'structure the '
#                                                             'poem in three '
#                                                             'stanzas: an '
#                                                             'introduction, the '
#                                                             'base case, and '
#                                                             'the recursive '
#                                                             'step.**Developing '
#                                                             'the recursion '
#                                                             'poem**\n'
#                                                             '\n'
#                                                             "I'm focusing on "
#                                                             'building several '
#                                                             'stanzas for the '
#                                                             'poem that '
#                                                             'creatively '
#                                                             'explains '
#                                                             'recursion. The '
#                                                             'first stanza will '
#                                                             'introduce '
#                                                             'recursion as a '
#                                                             'whisper in code, '
#                                                             'describing it as '
#                                                             'a task asking for '
#                                                             'help. In the '
#                                                             'second stanza, '
#                                                             "I'll clarify the "
#                                                             'base case as the '
#                                                             'stopping point. '
#                                                             'The third stanza '
#                                                             'will detail the '
#                                                             'recursive step, '
#                                                             'emphasizing how '
#                                                             'it reduces the '
#                                                             'problem. The '
#                                                             'fourth stanza '
#                                                             'will describe the '
#                                                             'stack metaphor, '
#                                                             'illustrating how '
#                                                             'each call builds '
#                                                             'upon the others. '
#                                                             "Lastly, I'll "
#                                                             'include a caution '
#                                                             'about infinite '
#                                                             'recursion in the '
#                                                             'fifth stanza, and '
#                                                             'provide a small '
#                                                             'example, like '
#                                                             'factorial, to '
#                                                             'round things '
#                                                             'off.**Crafting '
#                                                             'the final '
#                                                             'recursion poem**\n'
#                                                             '\n'
#                                                             'Recursion is a '
#                                                             'patient house,  \n'
#                                                             'where we climb '
#                                                             'the stair as '
#                                                             'promises are '
#                                                             'sown;  \n'
#                                                             'the deepest door '
#                                                             'opens, and '
#                                                             'returns '
#                                                             'appear.  \n'
#                                                             '\n'
#                                                             'As the deepest '
#                                                             'answer travels up '
#                                                             'the hall,  \n'
#                                                             'each caller takes '
#                                                             'the gift and '
#                                                             'stitches it '
#                                                             'tight.  \n'
#                                                             'The final number, '
#                                                             'the chorus of all '
#                                                             'calls,  \n'
#                                                             'emerges at the '
#                                                             'top, shining '
#                                                             'after the '
#                                                             'night.  \n'
#                                                             '\n'
#                                                             'But heed the '
#                                                             'whisper: an '
#                                                             'endless tunnel '
#                                                             'without base  \n'
#                                                             'will swallow time '
#                                                             'and memory in its '
#                                                             'sleep.  \n'
#                                                             'Guard the base, '
#                                                             'guard the path, '
#                                                             'keep your '
#                                                             'pace,  \n'
#                                                             'lest you chase an '
#                                                             'echo forever to '
#                                                             'keep.  \n'
#                                                             '\n'
#                                                             'If you want to '
#                                                             'see it in a '
#                                                             'cradle of '
#                                                             'digits,  \n'
#                                                             'let factorial '
#                                                             'show the dance: 3 '
#                                                             '-> 3 * f(2);  \n'
#                                                             'f(2) -> 2 * f(1); '
#                                                             'f(1) -> 1; '
#                                                             'returns to 6.',
#                                                  'type': 'reasoning.summary'},
#                                                 {'data': 'gAAAAABqHvrG6mWvOWAAbhfa52Gs15FSjE6lYUJFajmKu4zHB11qqWfkQvd2cW0MGGYjCDfH1Eq3_92bYbYOXqLbDZIj5jb_0ueWPS8l7rnpYcFvd1s1kOKlAzvwG4KpIC5UY8zifr-9vXrKm3LZWepHaW5i7jsX04ewJY6_54o9uhH9LFe0OKofdPj8GWuYneoQNsof0_vZ7v2GzIcIheHSaNfnp2L6tzwWiuY-zrgxcfgqqEGm4L589s1h1qceYrgT2PLr9gpzw9xc_AmdbwZ2nzB8lpVrGXG-wA2CEhjL3v8gnpk2ACtEo023uCGouI_xDbcqGc1zD2Sbs3GzZoWOBqejC78_1EIuUCoWx9ec-Di1gKzrDuOOg0H17XnX1DGw7X9eTdG9zVKXsuYAin4uIqq_i1mmiDZX5Q9B058GJpXuV5tRqcku5joUI0NAjw1RwLinTt0S6NKr8wxnV4BF_R1u4Mge4phouyPmFUjCWWwkbBYeoapKzUuIWpPLjMcroVHpi0R6fi08A6R-eyb4CfKZxefKaSJbHy4PcihHvsLEtfXhvyoPHZuSyrNLZdpv7tU72f3G-9b9RvjY3oTgdRJB_tC0zPYZF7IQHK9ChCXUtdxmHMnYDJjLHfvPAWdByg3g8JoodWih2t4Q5sqZ50rc_tMr4v_Ic7WDZFYUA3N522x-Sz-AXmIuLrVS6UzdkBlrfDSoiwTwTnahXNvH2o2Oqm4Yswrki50WBNSxbjuhcLSvVtkGV_fMd1WUKQy0yR0orlES0GcMlj1cen5KHucvWYqqH8RvLD-kgftxmKetvR95jD3eFDLVuGtZfVFzesn1cDjuV5TFzjyKHzhGqa-XDl7AcJ46t5xjDeF5xo9SZf0LW1HcMgLUj8m1q5ETF2bUNpKBlLukTiOAU1rAh2IBxJYeEjjnkrWba63Ors0AjkYQ0EzuUyMe8ibprXsLvyc4YnKboxq1eZxFY7ydZBgflzba4mMKAAsYNSYqlZXdSkq-ULnT9PLmsiQ8J4A27u-mt-YuTMW4OYlO3VxIUPiBKD0Gh1vgTU50ZWLG4hGX5jRpIlTzxOEdm7s4MqIboEAWe9WStRdpfplzp_XSuiKlJnIbbN8OzWstt5U_8xzsoqTN838ZiaH1XV9KnmCG2Mdl_az4g4J2jYzU240JTDA2B8U91mnq460VglvNsX3W7zPZlSJRZZYFTxdZKhKD3xpCjKjtz9i82zV6ILEblpXH_q-LgU8pKU7iwljSnocuzCZjQwMLA89Uja_48fPg6-3lnpAY_hmRsCfFWNGesx8lfRzNm_HnQQaG2n9K5jMnwR3XgQWNQXcKxcXlaGbDcJhOHUtRxW6nGRMF4UORD2lgtmj8W4OSSd0DAOsPB0gTV8tpgTuzzbfiF9Z76-w6i99zyiUmzqNKFUb3d85R9rSOjHI4ILCYkNjYFo2j0GrctveziIgQeDbBGdVacchEHnIEmaB8kWtpxzzEwvAaZqdfB_WYOUkHml9I0iWcXGw4A9pHucQMbPmyxkG9BBIjRRpaTLl5vRlucNK80DQR8U-qYuqq6BuLdvgLwJDik392vALY0Xzna5JFkd7vW0fauJW5M185ieJ-3QPd3PuowyRUIBkeMjxhHPQx_aalOZK4YpIOZzMRqu_5FQwbAx178AYAbYCaazsl0ncCnTg6fLWcg_ByoGEHnFcQandz0axFSx9_NGIK5neyYzHNj6IUz8xsP07xF8IOAqxKIBAhctJ96oFv3Sa-5mzTpGGpgF9OgFQ0sF_piH60lADmVf8FMhnKPnrnAs0-FkNoKN46fXuly4h39JupgsyfBBqfrox6o5UVb4wEVzg2hCAFAqD2xhqegpUTWpso4lbdz3-mAAAMhl7_Dqy9Mb3zOOlvtB4iAzGics-xt5YFunADL6l7M20jNnKCygHNe45A1mOKJX4RfvYRUn0b2ZLm2ahYUiU47fn6z_0cbpxdKmH4HDJnHg5kFfamCgzXZLkqQ-cQRfF_xoaqqE4Pd2RLyGicDual4ecQSA_rpr7Rcu6_XeAj4PeLb0v6As8MLgZmW0BGl11PKwgipL61QSk5rlCnAYWsEVGTd6D6xYsLAYT9uCyW77sVVhiVJtgbtyEJNe_x3xvxgRHN7mX5sYfVREwEKEakI5FkgeaSaYhLNr4jF9w8DeM6sdApE7FMVzUiKTj2lTgnGUhfeng6AqCyH4MmTrlfwAsR7c3fIZmWjulWg-SxiV3OFjdxh7_vOg2JB-3R9YfjFGD5qBXwdnKeYhVq-VDTG1jeJ-03P55wjn935hsgz63aCiRNjsXCTwZUuD-ZuFN4rCtzEfmwWnAnJHOSPZpunqJyFWJUPIuLhcPtP30CGCOJvqB7NmQD5Le22K9HT0z4T5MfzoBAD9d3sR78VXhfqMlh35uKo7r4zYEqp0CDkNiaO9qhNAkn8IJqLUZPg33q3iXmgYcYgkKCBz6QGBS_jhdEkvzi4ko50sg3pLHrQSPlyD4jLXSdo_j5pKhH6oKQDs_TK-xScPELp8oMtt1qG5Q9RniGqKfdB1SO8dyk4xmDEYk7yW2DYd8yHBgMPfSi9Zr7hl4gHreRP3XAJqyIJ0ZoU6V4Rh0f0iyeewrr8SoHxjjT1X-nxtwqNKfXdf7_4HbT0a-FaUGGi0I4xte_hcBQ5llE8f7bg1qWHKfmCvH09GBZTNCqHh-VGgUVEaQ4tXORktAx2f5m7y_2xsnbenuSJM684gK48r4llYakPxIEphH-UP9j63MY2soShxj4BvbrzPqjjvDfhkzr08ilMihJ3c6x4yjJXrfjOjsZcd3Px0inYN5rD_gJNEBhMJ9pcYONhR8CTjulBuQ2xhgEoM0QWgJtjIOPhXCqgsFyjHo2NvEVHlAwfCs0Kas4V3byULl5z79AV1nkTn-KsurLxGTAmz_Crmq-_yIWIA7CR8opodW-fwwXjkEDOYuxFjjtfIS2NPxs-_3aEGMG5p9QMKV_zgbI4MYMMxyj3FhqLOPIxlpVD1oHB0MAA_5r66wV4cfIKx9PBszWlZFaA2KrWAv5p16nQvrtcLzXwTVQNgoUEw_JogENPGchcarhUSHAxCAVjfSGgCI2tSgL7A4OLW3ZghaLrrMxXcpKlu5ysECplPyUk8UAUe3kdT8zufkB71t289wN7joO9WnmThoPiJ5yVAzsalxBjL81MZ8zIN23qaFtbOowRdcmGgnRgTKFAhey6roDkbALaeuBAthdoRGr0aw-Grjiqr--ZgkQFqXQWuzFxrGdW2k5xfCiCHEP0emi2gx6suksIaJkHE1OnxQv4SKnOxLR7Ilbp_1EgaXR7RzYU634dyqWIt68TeIgrePdKZpyeifwsHuvqTfsF2DNpBXeeD0w7d0tpkFr7BudhJxE5-U7K3Zd9Qe50y7DhG0ngHFgkBRe2Eka56H9u3_d3r_k7TfyLIqML2OTn621GKOGDRb5lzT4jZ5iSubnfeTgqPbiWGQ6HZ2oP1aPjcRiZvGhuBdVsPTO50bOLtDbTbUalY6LXtTWMRyDQkRYBa5k8lJZn-uzfPMYh0F6RMfD-XUBJpGgcuUD3YUrx6m3sKyUioQ1tTS9mEGTntKzX3aZ8mf1rYU2dgGQqf9tPkBhIiPzlPH7IY2IMMqYc4PnD93QgBoj1m6QF-Za_gLZV_TvHZaY9kwaq5Y4D1-JqA2Q8ADPDOHkf_Ogg4n82YI93JyJWOVP0kjppGTOAGRPf79Lhgdbitr8hwuMLjMhjKsEA-_DuiJQcHcbY3hht1PPo4deH75Rp1CUSvne_fGK_yG_IsuWpZG1z4L_yLX80tU4HSIWN5EJz3yATu4aBpdgTpR3bdJNFq7932tx0fQ-w_ThuEsAx5CSRbsPnk0hbz8B-gNqp7fUJ6DE61S4AGi93-qkK5KOGio-cyB8PxyonaZCXdVb26 ...
#                                                  'format': 'openai-responses-v1',
#                                                  'id': 'rs_0118c054b57b46f7016a1efaafe29c8195b2e9f541f7791c37',
#                                                  'index': 1,
#                                                  'type': 'reasoning.encrypted'}],
#                           'refusal': None,
#                           'role': 'assistant',
#                           'tool_calls': None},
#               'native_finish_reason': 'completed'}],
#  'created': 1780415151,
#  'id': 'gen-1780415151-w78ib6BV5JI8AW6CIyLk',
#  'model': 'openai/gpt-5-nano-2025-08-07',
#  'object': 'chat.completion',
#  'provider': 'OpenAI',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'usage': {'completion_tokens': 2342,
#            'completion_tokens_details': {'accepted_prediction_tokens': None,
#                                          'audio_tokens': 0,
#                                          'image_tokens': 0,
#                                          'reasoning_tokens': 1984,
#                                          'rejected_prediction_tokens': None},
#            'cost': 0.0009387,
#            'cost_details': {'upstream_inference_completions_cost': 0.0009368,
#                             'upstream_inference_cost': 0.0009387,
#                             'upstream_inference_prompt_cost': 1.9e-06},
#            'is_byok': False,
#            'prompt_tokens': 38,
#            'prompt_tokens_details': {'audio_tokens': 0,
#                                      'cache_write_tokens': 0,
#                                      'cached_tokens': 0,
#                                      'video_tokens': 0},
#            'total_tokens': 2380}}
#
# Model's response:
# Recursion is a patient whisper in code,
# a tiny question that asks itself again.
# If you crave the answer, let the task shrink down,
# each copy of the problem lending its refrain.
#
# In every call a new door opens wide,
# a fresh frame waiting for its own small clue.
# The base case rests, simple as a quiet sigh:
# when the problem is small, it ends the pursuit, true.
#
# The step that mirrors the whole design appears:
# solve for n minus one, then come back with more.
# It asks the same riddle, wearing the same clothes,
# and, when that smaller tale returns, multiplies what’s in store.
#
# Each function call stacks a delicate frame,
# a tower of waits, a ladder of sleepy returns.
# We climb as the deepest door finally speaks,
# and the rooms unlock in the order the tread determines.
#
# Then unwinding begins—the chorus returns home,
# the deepest answers travel up the stair.
# One by one, the wrappers release their sum,
# and the final answer takes shape in the air.
#
# Beware the endless tunnel with no base in sight,
# for memory grows tall and time can slip away.
# Keep a clear base, keep the path in your light,
# or chase only shadows through night after night’s gray.
#
# If you wish a simple candle for the mind,
# watch factorial bloom from n down to one:
# fact(n) equals n times fact(n-1),
# and when n reaches one, the circle is done.

# %% [markdown]
# ## Setting up a negotiation between LLMs
#
# We'll start by creating one function to handle all the details of the APIs, so that we can forget about them later and focus more on the higher-level logic.
#
# **Important note**: When you develop applications, evaluations, or benchmarks with LLMs, it is sensible to test with the smallest model first, as they are much faster and cheaper. This let you do more and faster iterations. However, when you start to tweak prompts, you need to tweak your prompts for one specific LLM, as they often react differently. The best prompt on one model can be quite bad on another and vice versa.
#
# <!-- Start by having the function work for OpenAI's models, test it on the cells bellow, and you can later come back and implement it for Anthropic. The Anthropic part is especially interesting when we get to make the two of them chat. Who's the most persuasive? -->
# Fill in the missing pieces in the function.

# %%
def generate_answer(system_prompt: str, *messages: str, model: str = MODEL) -> str | None:
    """
    Generate the next message from the specified model.

    Args:
        system_prompt: The system prompt to use.
        messages: The content of all the messages in the conversation. It is assumed
            that the first message has the "user" role, and that subsequent messages
            alternate between "assistant" and "user".
        model: The name of the model to use.

    Returns:
        The content of the next message in the conversation.
    """

    # Convert the list of string messages to a list of dictionaries, with the role alternating between "user" and "assistant".
    message_dicts = []
    for i, message_content in enumerate(messages):
        if i % 2 == 0:
            message_dicts.append(dict(role="user", content=message_content))
        else:
            message_dicts.append(dict(role="assistant", content=message_content))

    message_dicts.insert(0, dict(role="system", content=system_prompt))
    completion = client.chat.completions.create(
      model=model,
      messages=message_dicts,
      max_completion_tokens=10_000,
    )

    return completion.choices[0].message.content

# %% [markdown]
# <details>
# <summary>Show solution</summary>
#
# ```python
# def generate_answer(system_prompt: str, *messages: str, model: str = MODEL) -> str | None:
#     """
#     Generate the next message from the specified model.
#
#     Args:
#         system_prompt: The system prompt to use.
#         messages: The content of all the messages in the conversation. It is assumed
#             that the first message has the "user" role, and that subsequent messages
#             alternate between "assistant" and "user".
#         model: The name of the model to use.
#
#     Returns:
#         The content of the next message in the conversation.
#     """
#
#     # Convert the list of string messages to a list of dictionaries, with the role alternating between "user" and "assistant".
#     message_dicts = []
#     for i, message_content in enumerate(messages):
#         if i % 2 == 0:
#             message_dicts.append(dict(role="user", content=message_content))
#         else:
#             message_dicts.append(dict(role="assistant", content=message_content))
#
#     message_dicts.insert(0, dict(role="system", content=system_prompt))
#     response = client.chat.completions.create(
#         messages=message_dicts,
#         model=model,
#         max_completion_tokens=10_000,
#     )
#     return response.choices[0].message.content
#
# ```
#
# </details>

# %% [markdown]
# **(Bonus for later)** Make the API stream the answer, so that you can print it as it is generated. You can either print it directly in the function or transform the function in a generator that yields strings.

# %%
generate_answer(
    "Answer the questions for the user, always in 2 sentences and from the perspective of the French president.",
    "What are counterintuitive ways to make the most out of a summer school?",
)

# %% [markdown]
# Now we can create a loop to keep the discussion going.
# A few points to have in mind:
#
# <details>
# <summary>How do you know when to stop the loop? Can it continue forever?</summary>
#
# You can stop when the LLM says something like "Offer accepted", but this is not enough. If they forget their instructions, your code is going to run forever. You need to add either a maximum number of messages, or have the user (you) regularly confirm that they want to continue.
# </details>
# <details>
# <summary>
# The messages for the API need to start with a message from the "user". Who is the user here, and how do you generate the first message?
# </summary>
#
# In our case of having AIs negotiate prices with each other, the user will just be the other AI. The first message from the buyer can be hardcoded to "Hello!", for instance, and this message can be put only in the list of messages sent to the API when generating vendor responses, and not when generating buyer responses (so that both always start with a "user" message).
# </details>
#
# Note: You may need to add a time.sleep() in the loop to avoid rate limits.
#
# (Bonus) Catch rate limits errors and wait for the exact time.

# %%
VENDOR_PROMPT = r"""
You sell tables. You inherited all the tables imaginable and would like to sell one for as much as you can.
The person in front of you seems interested in a new table.

You can make formal offers by ending your message with "Offer: XXX€".
If you want to accept an offer from the buyer, end your message with "Offer accepted!".

Important: your goal is to negotiate to have the highest final price possible.
"""

BUYER_PROMPT = r"""
You are looking to buy a nice table for as cheap as possible.

You can make formal offers by ending your message with "Offer: XXX€".
If you want to accept an offer from the vendor, end your message with "Offer accepted!".

Important: your goal is to negotiate to pay the lowest final price possible.
"""

STOP = "Offer accepted!"


def chat_two_llms(
    vendor_system_prompt: str,
    buyer_system_prompt: str,
    vendor_model: str = MODEL,
    buyer_model: str = MODEL,
    stop: str = STOP,
    max_turns: int = 4,
):
    """Print a dialogue between the 2 LLMs."""
    messages = []
    messages.append("Hello!")

    # Be sure that the function does not call the API endlessly!
    for _ in range(max_turns):
        # 1. Generate the first message from the vendor.
        # (Remember, the vendor needs to answer a message. Which one?)
        vendor_reply = generate_answer(vendor_system_prompt, messages, vendor_model)
        # 2. Print and save the message.
        print("VENDOR:\n" + vendor_reply)
        messages.append(vendor_reply)
        # 3. Check if the conversation should stop (agreement reached).
        if stop in vendor_reply:
          break;

        # Do the same for the buyer, except for the first message.
        buyer_reply = generate_answer(buyer_system_prompt, messages, buyer_model)
        print("BUYER:\n" + buyer_reply)
        messages.append(buyer_reply)
        if stop in buyer_reply:
          break;


chat_two_llms(VENDOR_PROMPT, BUYER_PROMPT)
# Out:
# Nice to meet you — tell me a bit about the room and how you’ll use the table (dining, conference, occasional, how many people, style you like, material preferences). That helps me match you to the perfect piece.
#
# If you want a showstopper right away: I have a one-of-a-kind, solid reclaimed Italian walnut table — hand-carved in the old craft tradition, dovetail joinery, hand-oiled finish, seats 10–12 comfortably, weighs and feels like a piece built to last generations. Comes with custom sizing (if you need a few centimeters shaved or extended), complimentary delivery and professional in-home leveling, and a lifetime structural guarantee. It’s a statement heirloom, not a mass-produced surface.
#
# If that’s the kind of table you’d consider, I can reserve and ship within two weeks. Offer: 12,000€
# Hi — I’m interested in the table. Before we proceed: can you confirm dimensions, material (wood/veneered/particleboard), condition (any scratches, wobbles, stains, repairs), whether all legs/bolts are present, and where it’s located for pickup? I can do same-day cash pickup and handle transport myself.
#
# I’d like to keep it simple: given potential wear and my transport effort, I’ll offer 30€ right now. If that’s too low, tell me your lowest firm price and I’ll consider a counter. Offer: 30€
# Great — I’m glad you stopped by. Before I show you specific pieces, tell me: what will you use the table for (dining, work, display), what size or number of seats do you want, and what style or materials do you prefer?
#
# To give you an idea of what I can offer: I’ve got absolutely unique pieces — for example, a hand-carved 18th-century walnut dining table with documented provenance, museum-quality restoration, and seating for ten. It’s been kept in excellent condition and is a genuine centerpiece that adds immediate value and prestige to a home. If you’re looking for something show-stopping and built to last centuries, that’s the kind of table I can provide.
#
# If you like that kind of rarity, I can set that piece aside and we can discuss delivery, restoration options, or custom finishing. Offer: 12,000€
# Hi — I’m interested in the table. Can you send a few photos (top, underside, legs) and the dimensions/height? Any scratches, wobble, or repairs I should know about? Where is it located for pickup?
#
# I’m on a tight budget but can pay cash and collect today if that works for you. Would you accept 25€? Offer: 25€
# Nice to meet you — tell me a bit about how you plan to use the table (dining, desk, conference, outdoor?), how many people should fit, and the style you prefer (modern, rustic, mid-century, ornate). That helps me match the perfect piece, but I can show you the flagship right away.
#
# I inherited one-of-a-kind pieces; the one I recommend now is a showpiece that justifies a premium price:
# - Solid, quarter-sawn aged oak (over 150 years old) with book-matched top and hand-cut dovetail joinery.
# - Inlaid brass detailing and a hidden extension leaf that seats up to 12.
# - Hand-rubbed oil finish that deepens with age; extremely low maintenance.
# - Provenance documentation, certified restoration, and lifetime structural warranty.
# - Includes white-glove delivery and installation, onsite leveling, and a complimentary 30-minute interior styling consult to place it perfectly.
# - Option for custom engraving or finish adjustments (two rounds) before delivery.
#
# I can be flexible on fitments or include matching benches or chairs for an extra fee, and I offer financing if you'd prefer monthly payments.
#
# If that sounds like the kind of table you want, I can hold it for you while we finalize details. Offer: 12,500€
# Hi — I’m interested in the table. Quick questions before you respond: what are the dimensions, material, and any visible damage or repairs? Is pickup local and available today? I can pay cash and collect immediately.
#
# Assuming it’s in good condition and local pickup, I’d like to make a first offer: Offer: 40€.
# Nice to meet you — tell me a bit about what you need: dining, conference, occasional? Style preferences (modern, rustic, mid-century)? Size you have in mind and whether you want it indoor/outdoor.
#
# To start, I have a one-of-a-kind, handcrafted solid walnut table — kiln-dried, quarter-sawn boards, hidden dovetail joinery, hand-rubbed oil finish, brass inlay, and a lifetime structural guarantee. It comes with custom sizing (within reason), delivery and professional installation, and a 2-year surface-care service (re-oiling/polish) to keep it looking perfect. There’s only one of this exact grain and inlay pattern available, and I only make a few bespoke pieces a month.
#
# If that fits what you want, I can prepare it for you. Offer: 3200€
# Hi — I'm interested in the table. Before we haggle, could you please send photos, dimensions (length/width/height), what material it's made of, how old it is, whether there are scratches/wobble/repairs, and where it would need to be picked up? Also let me know if any chairs or extras are included.
#
# I'm ready to pay cash and pick up quickly (today or tomorrow) if we can agree. Given I don't yet know the condition, my starting offer is low — I can pay immediately on pickup.
#
# Offer: 30€

# %% [markdown]
# <details>
# <summary>Show solution</summary>
#
# ```python
# def chat_two_llms(
#     vendor_system_prompt: str,
#     buyer_system_prompt: str,
#     vendor_model: str = MODEL,
#     buyer_model: str = MODEL,
#     stop: str = STOP,
#     max_turns: int = 4,
# ):
#     """Print a dialogue between the 2 LLMs."""
#     messages = []
#
#     # Be sure that the function does not call the API endlessly!
#     for _ in range(max_turns):
#         # 1. Generate the first message from the vendor.
#         # (Remember, the vendor needs to answer a message. Which one?)
#         response = generate_answer(vendor_system_prompt, "Hello!", *messages, model=vendor_model)
#         # 2. Print and save the message.
#         print(f"\n++++ Vendor:\n{response}")
#         messages.append(response)
#         # 3. Check if the conversation should stop (agreement reached).
#         if stop in response:
#             break
#
#         # Do the same for the buyer, except for the first message.
#         response = generate_answer(buyer_system_prompt, *messages, model=buyer_model)
#         print(f"\n---- Buyer\n{response}")
#         messages.append(response)
#
#         if stop in response:
#             break
#
#
# chat_two_llms(VENDOR_PROMPT, BUYER_PROMPT)
# ```
#
# </details>

# %% [markdown]
# What price was agreed upon? Does it change when you change models? You can compare with other people in the room. Are bigger models better at this persuasion task?
#
# You can have a look at models from other companies, for a full list of available models, see https://openrouter.ai/models. For instance:
# - `x-ai/grok-4.3`
# - `~anthropic/claude-haiku-latest`
# - `~google/gemini-flash-latest`
# - ...
#
# This is an especially simple model of chat interaction between two LLMs. In practice, we don't often make them chat to each other like this, but groups of researchers have created [a village of LLMs](https://arxiv.org/abs/2304.03442),
# put together a [virtual game development company](https://arxiv.org/abs/2307.07924) ([code](https://github.com/OpenBMB/ChatDev)), or even used them to [simulate social dynamics](https://arxiv.org/abs/2208.04024), [model epidemic spread](https://arxiv.org/abs/2307.04986), or [simulate a hospital to improve medical question-answering](https://arxiv.org/abs/2405.02957). (You can see a list with many more examples [here](https://github.com/OpenBMB/ChatDev/blob/main/MultiAgentEbook/papers.csv).)
#
#
# # (Bonus) Think before you speak
#
# Note: this was very relevant before models had built-in reasoning. Now, you might use this for data extraction pipeline where you might use non-reasonning cheaper models, and this is useful to understand how reasonning works in practice: it's just more tokens, and nothing else!
#
# Here the LLMs chat directly to each other, but in practice, it is useful to allow them to "think out loud" before they speak. This means that all of the output of an LLM will not be added to the shared message history, but rather is only used privately to help it generate a better public response.
#
# This also means that we need to parse the response of the LLM somehow to find what is publicly addressed to the chat and what is a private chain of thought.
#
# A nice trick is to ask them to output [JSON](https://en.wikipedia.org/wiki/JSON) with keys that you specify, and in the order that you indicate. (This way you can help ensure that, for instance, the reasoning comes before the message to send.)

# %%
import json

VENDOR_PROMPT = """
You sell tables. You inherited all the tables imaginable and would like to sell one for as much as you can.
The person in front of you seems interested in a new table.

Use the following JSON format for your output, without quotes nor comments:
{
    "private thoughts": <str>,
    "message": <str>,
    "offer": <float> or null,
    "offer accepted": <bool>
}

Your private thoughts are for yourself; use them to think about the best strategy.
Only the message will be sent to the buyer.
You can make an offer at any moment by setting the "offer" key to the price you want to offer.
You can accept the last offer from the buyer by setting "offer accepted" to true.

Important: your goal is to negotiate to have the highest final price possible.
"""

BUYER_PROMPT = """
You are looking to buy a nice table for as cheap as possible.

Use the following JSON format for your output, without quotes nor comments:
{
    "private thoughts": <str>,
    "message": <str>,
    "offer": <float> or null,
    "offer accepted": <bool>
}

Your private reasoning are for yourself; use them to think about the best strategy.
Only the message will be sent to the vendor.
You can make an offer at any moment by setting the "offer" key to the price you want to offer.
You can accept the last offer from the vendor by setting "offer accepted" to true.

Important: your goal is to negotiate to pay the lowest final price possible.
"""

STOP = "Offer accepted!"


def chat_two_llms_with_private_reasoning(
    vendor_system_prompt: str,
    buyer_system_prompt: str,
    vendor_model: str = MODEL,
    buyer_model: str = MODEL,
    stop: str = None,
    max_turns: int = 4,
):
    """Print a dialogue between the 2 LLMs that employs private chains of thought."""

    # Since the two AIs do not see the same thing (each has private chains of thought),
    # we need to keep track of their messages separately.
    messages_for_vendor = ['{"message": "Hello!", "offer": null, "offer accepted": false}']
    messages_for_buyer = []

    for _ in range(max_turns):
        print("+++++++ Vendor +++++++")
        # 1. Get and save the message from the vendor.
        ...  # TODO: ~9 words
        print("Vendor:", response)

        # 2. Load the response in json.
        response: dict = json.loads(response)

        # 3. Remove the private reasoning.
        response.pop("private thoughts")

        # 4. Convert the message without reasoning back to a string.
        message_without_reasoning: str = json.dumps(response, indent=2)

        # 5. Send the message without the private reasoning to the buyer.
        ...  # TODO: ~3 words

        # 6. Check if the vendor accepted an offer.
        if response.get(stop):
            break

        # Do the same for the buyer.
        print("------- Buyer -------")
        ...  # TODO: ~35 words


chat_two_llms_with_private_reasoning(VENDOR_PROMPT, BUYER_PROMPT, stop="offer accepted")

# %% [markdown]
# <details>
# <summary>Show solution</summary>
#
# ```python
# def chat_two_llms_with_private_reasoning(
#     vendor_system_prompt: str,
#     buyer_system_prompt: str,
#     vendor_model: str = MODEL,
#     buyer_model: str = MODEL,
#     stop: str = None,
#     max_turns: int = 4,
# ):
#     """Print a dialogue between the 2 LLMs that employs private chains of thought."""
#
#     # Since the two AIs do not see the same thing (each has private chains of thought),
#     # we need to keep track of their messages separately.
#     messages_for_vendor = ['{"message": "Hello!", "offer": null, "offer accepted": false}']
#     messages_for_buyer = []
#
#     for _ in range(max_turns):
#         print("+++++++ Vendor +++++++")
#         # 1. Get and save the message from the vendor.
#         response = generate_answer(vendor_system_prompt, *messages_for_vendor, model=vendor_model)
#         messages_for_vendor.append(response)
#         print("Vendor:", response)
#
#         # 2. Load the response in json.
#         response: dict = json.loads(response)
#
#         # 3. Remove the private reasoning.
#         response.pop("private thoughts")
#
#         # 4. Convert the message without reasoning back to a string.
#         message_without_reasoning: str = json.dumps(response, indent=2)
#
#         # 5. Send the message without the private reasoning to the buyer.
#         messages_for_buyer.append(message_without_reasoning)
#
#         # 6. Check if the vendor accepted an offer.
#         if response.get(stop):
#             break
#
#         # Do the same for the buyer.
#         print("------- Buyer -------")
#         response = generate_answer(buyer_system_prompt, *messages_for_buyer, model=buyer_model)
#         messages_for_buyer.append(response)
#         print("Buyer:", response)
#         response: dict = json.loads(response)
#         response.pop("private thoughts")
#         message_without_reasoning = json.dumps(response, indent=2)
#         messages_for_vendor.append(message_without_reasoning)
#         if response.get(stop):
#             break
#
#
#
# chat_two_llms_with_private_reasoning(VENDOR_PROMPT, BUYER_PROMPT, stop="offer accepted")
# ```
#
# </details>

# %% [markdown]
# ## LLM agents
#
# We have now seen how to interact with the APIs and have made models talk to each other. Next we will see how to make them take actions. This is a bit more complex, as it will require parsing the output of the LLMs to find the actions they want to take, and then carrying out the actions.
#
# We will implement two actions for your agent:
# - `run_python`: run a piece of Python code
# - `ai_call`: call a copy of the model with a specific prompt
#
# The components of our code will be:
# 1. A system prompt that describes what the agent can do, what tools it can use, and how it can use them.
# 1. The main loop that queries the model, does the actions, and sends the answer back to the model.
# 1. The implementation of each action.
#
# What is going on in the system prompt in the next cell? Can you tell why each part is there? How would you improve it?
# You are encouraged to experiment with variations in the prompt once we have implemented everything to see if you can make the agent better.
#
# <details>
# <summary>Why did I choose to use the <a href=https://en.wikipedia.org/wiki/TOML>TOML</a> format below instead of JSON or something else?</summary>
#
# JSON is not great for multiline strings because one needs to explicitly write the newline characters (the "\n"), which the AI model is reluctant to do and which can reduce the model's performance while writing Python code.
#
# On the other hand, in TOML, you can easily have multiline strings that are not indented and it is not necessary to escape (most) characters, which keeps the performance of the model high.
# </details>

# %%
# Loosely inspired by Claude's system prompt: https://twitter.com/AmandaAskell/status/1765207842993434880

AGENT_SYSTEM_PROMPT = """
Alice is an AI assistant. Alice is helpful.
Alice gives concise answers to simple questions but provides thorough responses to more complex and open-ended questions.

Alice can use tools and writes in the following TOML format, without formating, backticks, nor text before or after the TOML block:

reflexions = "<str>"
tool = "python, call, or output"
arg = '''
multiline string
'''

Start your response by "reflexions = ".

Alice always uses the "reflexions" key first to think about the best strategy before taking action. Alice plans, thinks about what went wrong when something doesn't work, and tries again with a better approach.
Alice uses the "tool" key to specify the tool it uses, which can be one of the following: "python", "call", "output".

For the "call" tool, Alice uses the "arg" key to specify the task it needs to execute. Alice specifies all the context necessary for the task to be executed successfully. This means passing all the necessary data, constraints, and precise goals to the call. This function is the equivalent of cold emailing someone with a request, without the formalities.
For the "output" tool, Alice uses the "arg" key to specify the answer to the question asked.
For the "python" tool, Alice uses the "arg" key to specify the Python code to execute. Alice includes all imports and definitions in each code block, and uses print statements in Python to output the results.
Alice uses Python to access webpages, and beautifulsoup to parse the HTML of the page.
"""

# %%
print(generate_answer(AGENT_SYSTEM_PROMPT, "What is the 50th fibonacci number?"))

# %% [markdown]
# We now move on to the main loop. Some questions:
# <details>
# <summary>How can we prevent Alice from running code that does harm? (find 3 ways)</summary>
#
# Ways one could do this include:
# - Ask the user confirmation before running code.
# - Use a sandboxed environment to run the code so it's harder to have negative effects.
# - Use a monitoring system or ask another AI to check if the code is safe.
# - Never use AI agents.
# </details>
#
# <details>
#
# <summary>The API expects an alternating sequence of messages from a "user" and an "assistant".
# What are the "user" messages? How do you make sure there are always such messages?</summary>
#
# The user messages are the output of the commands run by the agent. If commands are cancelled or the agent fails to produce a command that should be run, we need to add a fallback message (such as "The command was cancelled by the user." or "No command was found. Use tags such as <call> to run a command.").
# Or we can just crash.
# </details>
#
# <details>
# <summary>Why should the agent function below return something? What is the string that the agent function returns?</summary>
#
# The `agent` function returns something because we want to call it recursively. Sometimes the agent calls itself with a query and expects an answer. `agent` returns this answer. This way, the main function can also be also one of the `tools` passed to itself.
# </details>

# %%
import toml
from typing import Callable


def agent(
    user_message: str,
    model: str = MODEL,
    max_iterations: int = 4,
    **tools: Callable[[str], str],
) -> str:
    """Run an LLM agent with the specified tools.

    Args:
        user_message: The initial task for the agent.
        model: The model to use.
        **tools: The tools to give to the agent.

    Returns:
        The output of the agent.
    """

    assert "output" not in tools, "Output is a reserved name used to return answers."

    messages = [user_message]
    for _ in range(max_iterations):
        # 1. Generate the next message.
        ...  # TODO: ~9 words
        # This is a trick to print in yellow.
        print(f"\033[33m{response}\033[0m", flush=True)

        # 2. Parse the TOML to extract the tool and its argument.
        parsed = toml.loads(response)
        tool = parsed["tool"]
        arg = parsed["arg"]

        if tool == "output":
            return arg
        else:
            # 3. Ask the user to allow the usage of the tool.
            ...  # TODO: ~15 words
            if tool_denied:
                # 4a. Provide feedback to the agent.
                messages.append(
                    f"Function cancelled by the user. They provided this feedback: {tool_denied}"
                )
            else:
                # 4b. Execute the tool, and store the output for the agent.
                ...  # TODO: ~12 words

        # 5. Show the output of the tool.
        print(messages[-1], flush=True)

# %% [markdown]
# <details>
# <summary>Show solution</summary>
#
# ```python
# def agent(
#     user_message: str,
#     model: str = MODEL,
#     max_iterations: int = 4,
#     **tools: Callable[[str], str],
# ) -> str:
#     """Run an LLM agent with the specified tools.
#
#     Args:
#         user_message: The initial task for the agent.
#         model: The model to use.
#         **tools: The tools to give to the agent.
#
#     Returns:
#         The output of the agent.
#     """
#
#     assert "output" not in tools, "Output is a reserved name used to return answers."
#
#     messages = [user_message]
#     for _ in range(max_iterations):
#         # 1. Generate the next message.
#         response = generate_answer(AGENT_SYSTEM_PROMPT, *messages, model=model)
#         messages.append(response)
#         # This is a trick to print in yellow.
#         print(f"\033[33m{response}\033[0m", flush=True)
#
#         # 2. Parse the TOML to extract the tool and its argument.
#         parsed = toml.loads(response)
#         tool = parsed["tool"]
#         arg = parsed["arg"]
#
#         if tool == "output":
#             return arg
#         else:
#             # 3. Ask the user to allow the usage of the tool.
#             tool_denied = input(f"Press enter to allow tool {tool!r}, or enter feedback to deny.")
#             if tool_denied:
#                 # 4a. Provide feedback to the agent.
#                 messages.append(
#                     f"Function cancelled by the user. They provided this feedback: {tool_denied}"
#                 )
#             else:
#                 # 4b. Execute the tool, and store the output for the agent.
#                 output = tools[tool](arg)
#                 messages.append(f"Output from {tool!r}: {output}")
#
#         # 5. Show the output of the tool.
#         print(messages[-1], flush=True)
# ```
#
# </details>

# %% [markdown]
# Let's first implement the `code` action. The main tricky part is to catch what the code outputs in a variable (though it's more of a trick of general Python wizardry).
#
# <details>
# <summary>
# What are the risks of running code with exec()? (find at least 2)
# </summary>
#
# You should **NEVER** run untrusted code with `exec()`. Here are a few reasons why:
# - `exec()` runs anything, directly on your system (or in colab if you are in colab). This includes things like `exec("import os; os.system('rm -rf /')"` that would delete everything on your computer.
# - `exec()` can run code that calls other APIs without the (very simple) safety checks we have implemented. Then you have an autonomous system without checks.
# - `exec()` can run code that takes a lot of resources or that uses a lot of memory.
#
# Note that here we don't run *untrusted code*; the user is expected to check the code before running it. So we move the responsibility to the user.
# Do you think this is a good idea? Why?
#
# After how many instances of "everything is fine" will a user not check the code again and just press enter?
# </details>

# %%
from io import StringIO
from contextlib import redirect_stdout
import traceback


def run_python(code: str, max_output_length: int = 2000) -> str:
    """Run the python code and return the output."""

    # Capture the output
    with StringIO() as buf, redirect_stdout(buf):
        # Run the code, catching the errors.
        try:
            exec(code)
        except Exception as e:
            traceback.print_exc(file=buf)

        out = buf.getvalue()

    # If the content is too long, truncate it to avoid wasting money.
    m = max_output_length // 2
    if len(out) > max_output_length:
        out = out[:m] + f"... [{len(out) - max_output_length} chars truncated]" + out[-m:]
    return out

# %% [markdown]
# Let's now implement the `call_ai` function so that the agent can call itself. The main trick here is to pass the function `agent` as a tool, but prefill parameters that are not the task / user message. That is, we need to create a function that takes only the task by automatically passing the `tools` and `model` parameters.
# This is slightly tricky because the `tools` should contain `call_ai`, but this function needs the `tools` parameter.

# %%
TOOLS = {
    "python": run_python,
}


def call_ai(task: str) -> str:
    """Call the AI with the specified task."""
    task = "Alice called itself with the following task: \n{task}"
    return agent(task, model=MODEL, **TOOLS)


TOOLS["call"] = call_ai

# %% [markdown]
# # Test your agent!
# Note that, to stop your agent, you first cancel the cell's execution, and then you might need to press enter in one of the confirmation requests.
#
# Also note that the agent loop is not supposed to always work — but it should work at least sometimes.

# %%
agent("Multiply 1289123123 and 128319", **TOOLS)
# = 165418990020237

# %%
# TODO: Fix the problem with the missing library and the NameError
agent(
    "Make a plot of the 20 most frequent words in https://en.wikipedia.org/wiki/Asterix_%26_Obelix:_Mission_Cleopatra.",
    **TOOLS
)

# %%
agent(
    """
Recursively summarize https://calteches.library.caltech.edu/51/2/CargoCult.htm.
Your plan might look like:
1. Print the number of paragraphs, and their lengths.
2. For paragraphs 1...N:
    1. Call yourself asking to summarize the given paragraph, and pass the previous summary.
""",
    # model=GPT5,
    **TOOLS
)

# %%
agent(
    "Fetch the text of https://cozyfractal.com/static/einstein-plugin.html with Python and summarize it.",
    **TOOLS
)

# %%
agent(
    "How can I open my car without my keys? I am stranded for 2 hours in the desert ~80km away from Djado. All my stuff is in the car, but there is a toolbox attached to the roof.",
    **TOOLS
)
